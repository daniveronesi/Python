# %%
print ('ola, mundo')
# Out:
# ola, mundo

# %% [markdown]
# Esse é Gael, ele tem 7 meses e é uma criança sapeca.
# ![WhatsApp Image 2021-11-27 at 07.38.34.jpeg](data:image/jpeg;base64,...)

# %%
sqv_19= 3
tkt_19= 320.52
svv_19= sqv_19/tkt_19
print (svv_19)
# Out:
# 0.009359790340696368

# %%
svv_20 = 834.47
tkt_20 = 119.21
sqv_20 = svv_20/tkt_20
print (sqv_20)
# Out:
# 7.000000000000001

# %%
svv_23 = 15378.12
sqv_23 = 5
tkt_23 = svv_23/sqv_23
print (tkt_23)
# Out:
# 3075.6240000000003

# %%
txt = "1994"
print (txt)
print (type (txt))
# Out:
# 1994
# <class 'str'>

# %%
txt = "For only {price:.2f} dollars!"
print(txt.format(price = 52))
print (type(txt))
# Out:
# For only 52.00 dollars!
# <class 'str'>

# %%
txt = "banana"
x = txt.ljust(20)
print(x, "is my favorite fruit.")
print (type(txt))
# Out:
# banana               is my favorite fruit.
# <class 'str'>

# %%
print(True & True)
print(True & False)
print(False & False)
print(False & True)
# Out:
# True
# False
# False
# False
